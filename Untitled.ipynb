# %%
import matplotlib.pyplot as plt
import pandas as pd
from pprint import pprint
file_names = ['2011.txt', '2012.txt', '2013.txt', '2014.txt', '2015.txt', '2016.txt', '2017.txt', '2018.txt', '2019.txt']
linii_without_end = ['\n<span id="line198572"', '\n<span id="line208034"', '\n<span id="line178017"', '\n<span id="line193702"', '\n<span id="line168945"', '\n<span id="line134083"', '\n<span id="line104273"', '\n<span id="line131510"', '\n<span id="line129229"']
linii_without_start = ['<span id="line1353"></span>',
                       '<span id="line1325"></span>',
                       '<span id="line1316"></span>',
                       '<span id="line1321"></span>',
                       '<span id="line1333"></span>',
                       '<span id="line1324"></span>',
                       '<span id="line1305"></span>',
                       '<span id="line1333"></span>',
                       '<span id="line1329"></span>']
data_universities_lst = []
for filename, end, start in zip(file_names, linii_without_end, linii_without_start):
    print(filename)
    html_code = open(filename, 'r').read()
    lst = html_code.split(end)
    data_universities_without_end = lst[0]
    lst_1 = data_universities_without_end.split(start)
    data_universities = lst_1[1]
    data_universities_lines = data_universities.split('\n')
    data_universities_lines = [line for line in data_universities_lines if '    ' in line]
    data_universities_lines = [i.split('    ')[1] for i in data_universities_lines]
    #pprint(data_universities_lines[:20])
    #pprint(data_universities_lines[-21:])
    
    len_data_universities_lines = len(data_universities_lines)
    
    if filename in ['2011.txt', '2012.txt']:
        for i in range(0, len_data_universities_lines, 11):
            oblast = data_universities_lines[i]

            university = data_universities_lines[i+1]

            ball = data_universities_lines[i+3]
            data_universities_lst.append([oblast, university, ball, filename[:4]])
        
    if filename in ['2013.txt', '2014.txt']:
        for i in range(0, len_data_universities_lines, 10):
            oblast = data_universities_lines[i]

            university = data_universities_lines[i+1]

            ball = data_universities_lines[i+2]
            data_universities_lst.append([oblast, university, ball, filename[:4]])

    if filename in ['2015.txt']:
        for i in range(0, len_data_universities_lines, 11):
            oblast = data_universities_lines[i]
            
            university = data_universities_lines[i+1]
            
            ball = data_universities_lines[i+2]
            data_universities_lst.append([oblast, university, ball, filename[:4]]) 
    if filename in ['2016.txt']:
        for i in range(0, len_data_universities_lines, 9):
            oblast = data_universities_lines[i]

            university = data_universities_lines[i+1]

            ball = data_universities_lines[i+2]
            data_universities_lst.append([oblast, university, ball, filename[:4]])
    if filename in ['2017.txt', '2018.txt', '2019.txt']:
        pprint(data_universities_lines[:20])
        for i in range(0, len_data_universities_lines, 7):
            oblast = data_universities_lines[i]

            university = data_universities_lines[i+1]

            ball = data_universities_lines[i+2]
            data_universities_lst.append([oblast, university, ball, filename[:4]])
        
    #pprint(data_universities_lst)
# Out:
# Matplotlib is building the font cache; this may take a moment.
# 2011.txt
# 2012.txt
# 2013.txt
# 2014.txt
# 2015.txt
# 2016.txt
# 2017.txt
# ['Физическая культура',
#  'Адыгейский гос. ун-т., г. Майкоп',
#  '63.3',
#  '-5.3',
#  '10',
#  '0',
#  'Нет',
#  'Информатика и вычислительная техника',
#  'Адыгейский гос. ун-т., г. Майкоп',
#  '57.8',
#  '5.7',
#  '44',
#  '0',
#  'Нет',
#  'Психолого-педагогическое и специальное (дефектологическое) образование',
#  'Адыгейский гос. ун-т., г. Майкоп',
#  '53.9',
#  '0.4',
#  '70',
#  '0']
# 2018.txt
# ['Реклама и связи с общественностью',
#  'Адыгейский гос. ун-т., г. Майкоп',
#  '70.2',
#  '5.9',
#  '13',
#  '0',
#  'Нет',
#  'Филология',
#  'Адыгейский гос. ун-т., г. Майкоп',
#  '77.4',
#  '7.3',
#  '20',
#  '1',
#  'Нет',
#  'Физическая культура',
#  'Адыгейский гос. ун-т., г. Майкоп',
#  '62.5',
#  '-0.8',
#  '10',
#  '0']
# 2019.txt
# ['Информатика и вычислительная техника',
#  'Адыгейский гос. ун-т., г. Майкоп',
#  '50.1',
#  '5.2',
#  '49',
#  '0',
#  'Нет',
#  'Автоматика и управление',
#  'Адыгейский гос. ун-т., г. Майкоп',
#  '48.5',
#  '-4.8',
#  '10',
#  '0',
#  'Нет',
#  'Психология',
#  'Адыгейский гос. ун-т., г. Майкоп',
#  '67.9',
#  '4.8',
#  '10',
#  '0']

# %%
df = pd.DataFrame(data_universities_lst)
df.columns = ['oblast', 'university', 'ball', 'year']
df = df.sort_values(by=['university', 'oblast', 'year'])
df['ball'] = [float(i) if i != '' else '' for i in df['ball']]
df.head()
# Out:
#                         oblast                        university  ball  year
# 1      Автоматика и управление  Адыгейский гос. ун-т., г. Майкоп  59.1  2011
# 5647   Автоматика и управление  Адыгейский гос. ун-т., г. Майкоп    37  2012
# 11551  Автоматика и управление  Адыгейский гос. ун-т., г. Майкоп  49.4  2013
# 17068  Автоматика и управление  Адыгейский гос. ун-т., г. Майкоп  49.5  2014
# 23088  Автоматика и управление  Адыгейский гос. ун-т., г. Майкоп  52.6  2015

# %%
df.to_csv('data.csv')
data.csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-997c3c6ed410> in <module>
#       1 df.to_csv('data.csv')
# ----> 2 data.csv
#
# NameError: name 'data' is not defined

# %%
df_spb = df[df['university'] == 'Санкт-Петербургский гос. архитектурно-строительный ун-т.']
df_spb = df[df['university'] == 'Санкт-Петербургский гос. архитектурно-строительный ун-т.']
df_spb = df_spb[df_spb['oblast'] == 'Энергетика и энергетическое машиностроение']
df_spb['ball'] = [float(i) for i in df_spb['ball']]
df_spb.sort_values(by='year')
df_spb
# Out:
#                                            oblast  \
# 3962   Энергетика и энергетическое машиностроение
# 9821   Энергетика и энергетическое машиностроение
# 15460  Энергетика и энергетическое машиностроение
# 21273  Энергетика и энергетическое машиностроение
# 26428  Энергетика и энергетическое машиностроение
# 31047  Энергетика и энергетическое машиностроение
# 35529  Энергетика и энергетическое машиностроение
# 40763  Энергетика и энергетическое машиностроение
# 46338  Энергетика и энергетическое машиностроение
#
#                                               university  ball  year
# 3962   Санкт-Петербургский гос. архитектурно-строител...  65.6  2011
# 9821   Санкт-Петербургский гос. архитектурно-строител...  64.0  2012
# 15460  Санкт-Петербургский гос. архитектурно-строител...  67.6  2013
# 21273  Санкт-Петербургский гос. архитектурно-строител...  62.6  2014
# 26428  Санкт-Петербургский гос. архитектурно-строител...  71.0  2015
# 31047  Санкт-Петербургский гос. архитектурно-строител...  67.5  2016
# 35529  Санкт-Петербургский гос. архитектурно-строител...  69.4  2017
# 40763  Санкт-Петербургский гос. архитектурно-строител...  70.0  2018
# 46338  Санкт-Петербургский гос. архитектурно-строител...  72.6  2019

# %%
df_spb = df[df['university'] == 'Санкт-Петербургский гос. архитектурно-строительный ун-т.']
df_spb = df[df['university'] == 'Санкт-Петербургский гос. архитектурно-строительный ун-т.']
df_spb = df_spb[df_spb['oblast'] == 'Архитектура и строительство']
df_spb['ball'] = [float(i) for i in df_spb['ball']]
df_spb.sort_values(by='year')
df_spb
# Out:
#                             oblast  \
# 3965   Архитектура и строительство
# 9828   Архитектура и строительство
# 15458  Архитектура и строительство
# 21269  Архитектура и строительство
# 26426  Архитектура и строительство
# 31041  Архитектура и строительство
# 35528  Архитектура и строительство
#
#                                               university  ball  year
# 3965   Санкт-Петербургский гос. архитектурно-строител...  78.8  2011
# 9828   Санкт-Петербургский гос. архитектурно-строител...  69.5  2012
# 15458  Санкт-Петербургский гос. архитектурно-строител...  80.5  2013
# 21269  Санкт-Петербургский гос. архитектурно-строител...  83.1  2014
# 26426  Санкт-Петербургский гос. архитектурно-строител...  83.6  2015
# 31041  Санкт-Петербургский гос. архитектурно-строител...  82.6  2016
# 35528  Санкт-Петербургский гос. архитектурно-строител...  84.1  2017

# %%
x = list(df_spb['year'])
y = list(df_spb['ball'])
plt.plot(x, y)

# %%
#df_arch = df[df['oblast'] == 'Архитектура и строительство']
#set_arch = set(df_arch['university'])

# %%
#df_arch = df[df['university'] == 'архитектурно-строительный ун-т']
#set_arch = set(df_arch['university'])

# %%
set_arch = set([i for i in df['university'] if 'архитектурно-строительный ун-т' in i])
set_arch
# Out:
# {'Волгоградский гос. архитектурно-строительный ун-т.',
#  'Воронежский гос. архитектурно-строительный ун-т.',
#  'Ивановский гос. архитектурно-строительный ун-т.',
#  'Казанский гос. архитектурно-строительный ун-т.',
#  'Нижегородский гос. архитектурно-строительный ун-т.',
#  'Новосибирский гос. архитектурно-строительный ун-т.',
#  'Самарский гос. архитектурно-строительный ун-т.',
#  'Санкт-Петербургский гос. архитектурно-строительный ун-т.',
#  'Томский гос. архитектурно-строительный ун-т.',
#  'Тюменский гос. архитектурно-строительный ун-т.'}

# %%
df_arch = df[df['university'].isin(set_arch)]
df_arch = df_arch[df_arch['oblast'].isin(['Архитектура и строительство', 'Архитектура и градостроительство'])]
df_arch.to_csv('df_arch.csv')
df_arch
# Out:
#                             oblast  \
# 577    Архитектура и строительство
# 6212   Архитектура и строительство
# 12094  Архитектура и строительство
# 17638  Архитектура и строительство
# 23546  Архитектура и строительство
# ...                            ...
# 4989   Архитектура и строительство
# 10903  Архитектура и строительство
# 16431  Архитектура и строительство
# 22369  Архитектура и строительство
# 27305  Архитектура и строительство
#
#                                               university  ball  year
# 577    Волгоградский гос. архитектурно-строительный у...  63.5  2011
# 6212   Волгоградский гос. архитектурно-строительный у...    57  2012
# 12094  Волгоградский гос. архитектурно-строительный у...  64.1  2013
# 17638  Волгоградский гос. архитектурно-строительный у...  59.3  2014
# 23546  Волгоградский гос. архитектурно-строительный у...  66.9  2015
# ...                                                  ...   ...   ...
# 4989      Тюменский гос. архитектурно-строительный ун-т.  80.5  2011
# 10903     Тюменский гос. архитектурно-строительный ун-т.  43.8  2012
# 16431     Тюменский гос. архитектурно-строительный ун-т.  78.4  2013
# 22369     Тюменский гос. архитектурно-строительный ун-т.  81.1  2014
# 27305     Тюменский гос. архитектурно-строительный ун-т.  82.5  2015
#
# [69 rows x 4 columns]

# %%
set([i for i in df['oblast'] if 'рхитектур' in i])
# Out:
# {'Архитектура и градостроительство', 'Архитектура и строительство'}

# %%
for university, group in df_arch.groupby('university'):
    x = list(group['year'])
    y = list(group['ball'])
    plt.plot(x, y)
    break
